# %% [markdown]
# <a href="https://colab.research.google.com/github/catcodey/LGM-PYTHON/blob/main/gif.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install moviepy

# %%
from PIL import Image
import matplotlib.pyplot as plt

image_path = "image2.jpg"
# Open the image file
img2 = Image.open(image_path)

# Display the image
plt.imshow(img2)
img2=img2.resize((612,408))
print(img2.size)
# Out:
# (612, 408)

# %%
image_path = "image3.jpg"
# Open the image file
img3 = Image.open(image_path)

# Display the image
plt.imshow(img3)
img3=img3.resize((612,408))
print(img3.size)
# Out:
# (612, 408)

# %%
image_path = "image1.jpg"
# Open the image file
image1 = Image.open(image_path)

# Display the image
plt.imshow(image1)
image1=image1.resize((612,408))
print(image1.size)
# Out:
# (612, 408)

# %%
|plt.imshow(img1)

# %%
from moviepy.editor import ImageSequenceClip
from PIL import Image
import numpy as np
from IPython.display import display, Image as IPImage

def resize_image(image_path, new_size):
    img = Image.open(image_path)
    img_resized = img.resize(new_size)
    return img_resized

def pil_to_np(image):
    return np.array(image)

def create_and_display_gif(image_paths, fps=1, target_size=(612, 408)):
    resized_images = [pil_to_np(resize_image(path, target_size)) for path in image_paths]

    clip = ImageSequenceClip(resized_images, fps=fps)
    gif_path = "output.gif"
    clip.write_gif(gif_path, fps=fps)

    # Display the GIF in the notebook
    with open(gif_path, "rb") as f:
        display(IPImage(data=f.read(), format="jpg"))

# Example usage:
image_paths = ["image1.jpg", "image2.jpg", "image3.jpg"]
create_and_display_gif(image_paths, fps=0.5)
# Out:
# MoviePy - Building file output.gif with imageio.
